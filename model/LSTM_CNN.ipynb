# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import modules

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sys, os, re, csv, codecs, numpy as np, pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Reshape, Conv2D, Concatenate, Flatten
from keras.layers import Bidirectional, GlobalMaxPool1D, SpatialDropout1D, MaxPool2D, BatchNormalization, Wrapper, InputSpec, TimeDistributed, concatenate
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import numpy as np
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split, KFold, StratifiedShuffleSplit, StratifiedKFold
from sklearn.metrics import (
      accuracy_score,
      recall_score,
      precision_score,
      f1_score, roc_curve, auc)
from keras.callbacks import EarlyStopping, ModelCheckpoint
early_stopping = EarlyStopping(monitor='val_loss', patience=4,restore_best_weights=True,verbose=0)
callbacks=[early_stopping]
from keras import backend as K
import tensorflow as tf
import keras
import pandas as pd
from tensorflow.keras.optimizers import Adam
from gensim.models import KeyedVectors
import string

# %% [markdown]
# # Load data

# %%
# !git clone https://github.com/anonymoususr12/MHPurf

# %%
# %cd MHPurf/data
project = 'tensorflow' # select in [tensorflow, pytorch, keras, incubator-mxnet, caffe]
path = f'{project}.csv'
pd_all = pd.read_csv(path)
pd_all = pd_all.sample(frac=1,random_state=999)
pd_all['Title+Body'] = ''
for idx in range(len(pd_all)):
  if pd.notna(pd_all['Body'].iloc[idx]):
    pd_all['Title+Body'].iloc[idx] = pd_all['Title'].iloc[idx] + '. ' + pd_all['Body'].iloc[idx]
  else:
    pd_all['Title+Body'].iloc[idx] = pd_all['Title'].iloc[idx]
pd_title = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Title":"text"})
pd_title.to_csv('Title.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_body = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Body":"text"})
pd_body.to_csv('Body.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_label = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Labels":"text"})
pd_label.to_csv('Labels.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_code = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Codes":"text"})
pd_code.to_csv('Codes.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_comment = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Comments":"text"})
pd_comment.to_csv('Comments.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_command = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Commands":"text"})
pd_command.to_csv('Command.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")
pd_tplusb = pd_all.rename(columns={"Unnamed: 0":"id","class":"sentiment","Title+Body":"text"})
pd_tplusb.to_csv('Title+Body.csv', index=False, columns=["id","Number","sentiment","text"], mode="w")

# %% [markdown]
# # Training

# %%
##################### GLOBAL ###################
NETWORK = 'LSTM' # choose LSTM or CNN

REPEAT = 30
repeated_range = range(0,REPEAT)

max_features = 1000
MAX_LEN = 250

embed_size = 100 # how big is each word vector
CV_TIME = 10

out_csv_name = f'../{project}_{NETWORK}'

if NETWORK == 'LSTM':
  out_csv_name += '_LSTM'
elif NETWORK == 'CNN':
  out_csv_name += '_CNN'

data = pd.read_csv('Title+Body.csv')
data = data.rename(columns={"sentiment": "target"})
#################################################
for i in range(len(data['text'])):
    data['text'].iloc[i] = str(data['text'].iloc[i])

# Preprocessing

import re

# removing URLs

def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)

data["text"] = data["text"].apply(lambda x: remove_url(x))

# removing html

def remove_html(text):
    html = re.compile(r'<.*?>')
    return html.sub(r'', text)

data["text"] = data["text"].apply(lambda x: remove_html(x))

# removing emoji

def remove_emoji(text):
    emoji_pattern = re.compile("["
                              u"\U0001F600-\U0001F64F" #emoticons
                              u"\U0001F300-\U0001F5FF" #symbols&pics
                              u"\U0001F680-\U0001F6FF" #transportation pic
                              u"\U0001F1E0-\U0001F1FF" #flags
                              u"\U00002702-\U000027B0"
                              u"\U000024C2-\U0001F251"    
                              "]+", flags = re.UNICODE)
    return emoji_pattern.sub(r'', text)

data["text"] = data["text"].apply(lambda x: remove_emoji(x))

# Stop Word Removal
NLTK_stop_words_list = stopwords.words('english')
custom_stop_words_list = ['...']
final_stop_words_list = NLTK_stop_words_list + custom_stop_words_list
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in final_stop_words_list])

data["text"] = data["text"].apply(lambda text: remove_stopwords(text))

# Symbol removal
def clean_str(string):
    string = re.sub(r"[^A-Za-z0-9(),.!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    string = re.sub(r"\\", "", string)
    string = re.sub(r"\'", "", string)
    string = re.sub(r"\"", "", string)
    return string.strip().lower()

data["text"] = data["text"].apply(lambda text: clean_str(text))

# Word2Vec Embedding
list_sentences = data["text"].fillna("").values
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences))
list_tokenized = tokenizer.texts_to_sequences(list_sentences)
y = data["target"]
data = pad_sequences(list_tokenized, maxlen=MAX_LEN)

def load_word2vec_embeddings(filepath, tokenizer, max_features, embedding_size):
    model = KeyedVectors.load_word2vec_format(filepath,limit=500000)

    emb_mean, emb_std = model.wv.syn0.mean(), model.wv.syn0.std()

    word_index = tokenizer.word_index
    nb_words = min(max_features, len(word_index))
    embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embedding_size))
    for word, i in word_index.items():
        if i > max_features:
            continue
        try:
            embedding_vector = model[word]
            embedding_matrix[i-1] = embedding_vector
        except KeyError:
            continue
    return embedding_matrix

# embedding_matrix = load_word2vec_embeddings("/content/drive/MyDrive/data_only/embedding/enwiki_20180420_100d.txt.bz2",
#                                             tokenizer,
#                                             max_features,
#                                             embed_size)
embedding_matrix = load_word2vec_embeddings("embedding/enwiki_20180420_100d.txt.bz2",
                                            tokenizer,
                                            max_features,
                                            embed_size)

# Model Construction
def build_model(max_len):
    if NETWORK == 'LSTM':
      # LSTM begin
      inp = Input(shape=(MAX_LEN,))
      x = Dropout(0.1)(inp)
      x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
      x = LSTM(100)(x)
      x = Dense(100, activation="relu")(x)
      x = Dropout(0.1)(x)
      x = Dense(2, activation="softmax")(x)
    
    if NETWORK == 'CNN':
      # cPur (CNN) begin
      filter_sizes = [3,4,5]
      num_filters = 2
      maxlen = MAX_LEN
      inp = Input(shape=(maxlen,))
      x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
      x = SpatialDropout1D(0.2)(x)
      x = Reshape((maxlen, embed_size, 1))(x)
      conv_0 = Conv2D(num_filters, kernel_size=(filter_sizes[0], embed_size), kernel_initializer='normal',
                                                                                      activation='elu')(x)
      conv_1 = Conv2D(num_filters, kernel_size=(filter_sizes[1], embed_size), kernel_initializer='normal',
                                                                                      activation='elu')(x)
      conv_2 = Conv2D(num_filters, kernel_size=(filter_sizes[2], embed_size), kernel_initializer='normal',
                                                                                      activation='elu')(x)
      maxpool_0 = MaxPool2D(pool_size=(maxlen - filter_sizes[0] + 1, 1))(conv_0)
      maxpool_1 = MaxPool2D(pool_size=(maxlen - filter_sizes[1] + 1, 1))(conv_1)
      maxpool_2 = MaxPool2D(pool_size=(maxlen - filter_sizes[2] + 1, 1))(conv_2)
      z = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])   
      z = Flatten()(z)
      x = Dense(2, activation="softmax")(z)
    
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Training
macro = []
micro = []
auc_value = []
for repeated_time in repeated_range:
    cv_time = 1
    X_train, X_test, y_train, y_test = train_test_split(data,y,test_size=0.2, random_state=repeated_time)
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()
  
    model = build_model(MAX_LEN)
    y_train = to_categorical(np.asarray(y_train))
    model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.1,callbacks=[early_stopping])
    y_pred = model.predict(X_test, batch_size=1024, verbose=1).round().astype(int)
    y_true = y_test
    y_true = to_categorical(np.asarray(y_true))
    current_macro=f1_score(y_true,y_pred,average='macro')
    macro.append(current_macro)
    current_micro=f1_score(y_true,y_pred,average='micro')
    micro.append(current_micro)
    fpr, tpr, thresholds = roc_curve(y_true[:,1], y_pred[:,1], pos_label=1)
    current_auc = auc(fpr, tpr)
    auc_value.append(current_auc)

    new_row = {'repeated_times':REPEAT,'cv_list':str(auc_value),'Macro F1':sum(macro) / len(macro), 'Micro F1':sum(micro) / len(micro), 'AUC':sum(auc_value) / len(auc_value)}
    df_log = pd.DataFrame(columns=['repeated_time','cv_list','Macro F1', 'Micro F1', 'AUC'])
    df_log = df_log.append(new_row, ignore_index=True)
    df_log.to_csv(out_csv_name, mode='a', header=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:98: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:98: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# Epoch 1/100
# 17/17 [==============================] - 6s 43ms/step - loss: 0.5187 - accuracy: 0.7910 - val_loss: 0.4758 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4823 - accuracy: 0.8116 - val_loss: 0.4772 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4695 - accuracy: 0.8116 - val_loss: 0.4522 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4363 - accuracy: 0.8106 - val_loss: 0.4299 - val_accuracy: 0.8250
# Epoch 5/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3803 - accuracy: 0.8340 - val_loss: 0.4277 - val_accuracy: 0.8083
# Epoch 6/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3220 - accuracy: 0.8666 - val_loss: 0.4619 - val_accuracy: 0.7333
# Epoch 7/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2863 - accuracy: 0.8862 - val_loss: 0.4284 - val_accuracy: 0.8167
# Epoch 8/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2382 - accuracy: 0.9058 - val_loss: 0.4053 - val_accuracy: 0.8083
# Epoch 9/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1811 - accuracy: 0.9394 - val_loss: 0.4836 - val_accuracy: 0.7833
# Epoch 10/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1606 - accuracy: 0.9506 - val_loss: 0.5299 - val_accuracy: 0.8417
# Epoch 11/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1254 - accuracy: 0.9571 - val_loss: 0.5524 - val_accuracy: 0.8000
# Epoch 12/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1025 - accuracy: 0.9627 - val_loss: 0.5847 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 325ms/step
#
#  Average Macro F1 is  0.6499580486635502  after running time 0
#
#  Average F1 is  0.8355704697986577  after running time 0
#
#  Total AUC is  0.6248784137673027  after running time 0
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5125 - accuracy: 0.8162 - val_loss: 0.6057 - val_accuracy: 0.7250
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4575 - accuracy: 0.8209 - val_loss: 0.6422 - val_accuracy: 0.7250
# Epoch 3/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4365 - accuracy: 0.8209 - val_loss: 0.5563 - val_accuracy: 0.7250
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4171 - accuracy: 0.8218 - val_loss: 0.5608 - val_accuracy: 0.7250
# Epoch 5/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3599 - accuracy: 0.8451 - val_loss: 0.6159 - val_accuracy: 0.7333
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2975 - accuracy: 0.8806 - val_loss: 0.5712 - val_accuracy: 0.7583
# Epoch 7/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2393 - accuracy: 0.9086 - val_loss: 0.4404 - val_accuracy: 0.8333
# Epoch 8/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1979 - accuracy: 0.9291 - val_loss: 0.4205 - val_accuracy: 0.8417
# Epoch 9/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1557 - accuracy: 0.9478 - val_loss: 0.5689 - val_accuracy: 0.8167
# Epoch 10/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1238 - accuracy: 0.9534 - val_loss: 0.5112 - val_accuracy: 0.8417
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0875 - accuracy: 0.9701 - val_loss: 0.5434 - val_accuracy: 0.8417
# Epoch 12/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1504 - accuracy: 0.9431 - val_loss: 0.5583 - val_accuracy: 0.8333
# 1/1 [==============================] - 0s 268ms/step
#
#  Average Macro F1 is  0.6610626326926112  after running time 1
#
#  Average F1 is  0.825503355704698  after running time 1
#
#  Total AUC is  0.6443305244307066  after running time 1
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5588 - accuracy: 0.7556 - val_loss: 0.3841 - val_accuracy: 0.8750
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5020 - accuracy: 0.7985 - val_loss: 0.3918 - val_accuracy: 0.8750
# Epoch 3/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4874 - accuracy: 0.7985 - val_loss: 0.4125 - val_accuracy: 0.8750
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4625 - accuracy: 0.7985 - val_loss: 0.4091 - val_accuracy: 0.8750
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4120 - accuracy: 0.8125 - val_loss: 0.4799 - val_accuracy: 0.8000
# 1/1 [==============================] - 0s 277ms/step
#
#  Average Macro F1 is  0.5927765483157554  after running time 2
#
#  Average F1 is  0.8299776286353469  after running time 2
#
#  Total AUC is  0.5962203496204711  after running time 2
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5591 - accuracy: 0.7584 - val_loss: 0.4137 - val_accuracy: 0.8583
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4960 - accuracy: 0.8004 - val_loss: 0.4199 - val_accuracy: 0.8583
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4754 - accuracy: 0.8004 - val_loss: 0.3630 - val_accuracy: 0.8583
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4500 - accuracy: 0.8013 - val_loss: 0.3687 - val_accuracy: 0.8583
# Epoch 5/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4256 - accuracy: 0.8022 - val_loss: 0.3127 - val_accuracy: 0.8583
# Epoch 6/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3515 - accuracy: 0.8573 - val_loss: 0.2823 - val_accuracy: 0.8667
# Epoch 7/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3000 - accuracy: 0.8759 - val_loss: 0.2482 - val_accuracy: 0.9000
# Epoch 8/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2604 - accuracy: 0.9039 - val_loss: 0.2520 - val_accuracy: 0.9083
# Epoch 9/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2069 - accuracy: 0.9142 - val_loss: 0.2686 - val_accuracy: 0.9083
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2284 - accuracy: 0.9030 - val_loss: 0.3368 - val_accuracy: 0.8667
# Epoch 11/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2686 - accuracy: 0.8899 - val_loss: 0.2652 - val_accuracy: 0.8833
# 1/1 [==============================] - 0s 275ms/step
#
#  Average Macro F1 is  0.6267180387671809  after running time 3
#
#  Average F1 is  0.8422818791946309  after running time 3
#
#  Total AUC is  0.6202485955486866  after running time 3
# Epoch 1/100
# 17/17 [==============================] - 2s 43ms/step - loss: 0.5311 - accuracy: 0.8078 - val_loss: 0.4285 - val_accuracy: 0.8500
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4856 - accuracy: 0.8078 - val_loss: 0.4140 - val_accuracy: 0.8500
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4709 - accuracy: 0.8078 - val_loss: 0.4136 - val_accuracy: 0.8500
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4435 - accuracy: 0.8078 - val_loss: 0.3909 - val_accuracy: 0.8500
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3948 - accuracy: 0.8172 - val_loss: 0.4031 - val_accuracy: 0.8333
# Epoch 6/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3326 - accuracy: 0.8647 - val_loss: 0.3802 - val_accuracy: 0.8667
# Epoch 7/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3169 - accuracy: 0.8759 - val_loss: 0.3925 - val_accuracy: 0.8417
# Epoch 8/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2524 - accuracy: 0.9021 - val_loss: 0.3955 - val_accuracy: 0.8417
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2256 - accuracy: 0.9114 - val_loss: 0.3763 - val_accuracy: 0.8667
# Epoch 10/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1739 - accuracy: 0.9384 - val_loss: 0.4413 - val_accuracy: 0.8500
# Epoch 11/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1410 - accuracy: 0.9459 - val_loss: 0.5309 - val_accuracy: 0.8583
# Epoch 12/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1117 - accuracy: 0.9646 - val_loss: 0.5094 - val_accuracy: 0.8667
# Epoch 13/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0857 - accuracy: 0.9692 - val_loss: 0.5082 - val_accuracy: 0.8250
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f40fbe8d050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 270ms/step
#
#  Average Macro F1 is  0.6242283193848744  after running time 4
#
#  Average F1 is  0.840268456375839  after running time 4
#
#  Total AUC is  0.6151363998209172  after running time 4
# Epoch 1/100
# 17/17 [==============================] - 2s 42ms/step - loss: 0.5438 - accuracy: 0.7854 - val_loss: 0.4541 - val_accuracy: 0.8333
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4877 - accuracy: 0.8050 - val_loss: 0.4465 - val_accuracy: 0.8333
# Epoch 3/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4691 - accuracy: 0.8050 - val_loss: 0.4348 - val_accuracy: 0.8333
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4326 - accuracy: 0.8078 - val_loss: 0.4197 - val_accuracy: 0.8333
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3664 - accuracy: 0.8405 - val_loss: 0.4930 - val_accuracy: 0.7333
# Epoch 6/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3480 - accuracy: 0.8545 - val_loss: 0.3874 - val_accuracy: 0.8583
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2739 - accuracy: 0.8825 - val_loss: 0.3902 - val_accuracy: 0.8333
# Epoch 8/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2153 - accuracy: 0.9226 - val_loss: 0.3324 - val_accuracy: 0.8750
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1635 - accuracy: 0.9375 - val_loss: 0.4077 - val_accuracy: 0.8000
# Epoch 10/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1274 - accuracy: 0.9515 - val_loss: 0.4225 - val_accuracy: 0.8917
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0841 - accuracy: 0.9701 - val_loss: 0.4468 - val_accuracy: 0.8833
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0730 - accuracy: 0.9739 - val_loss: 0.5333 - val_accuracy: 0.8417
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f40fcda1cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 557ms/step
#
#  Average Macro F1 is  0.6387924166916964  after running time 5
#
#  Average F1 is  0.8400447427293066  after running time 5
#
#  Total AUC is  0.6312158170550654  after running time 5
# Epoch 1/100
# 17/17 [==============================] - 2s 47ms/step - loss: 0.5409 - accuracy: 0.7836 - val_loss: 0.4503 - val_accuracy: 0.8333
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4771 - accuracy: 0.8181 - val_loss: 0.4448 - val_accuracy: 0.8333
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4586 - accuracy: 0.8181 - val_loss: 0.4385 - val_accuracy: 0.8333
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4313 - accuracy: 0.8181 - val_loss: 0.4238 - val_accuracy: 0.8333
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3985 - accuracy: 0.8218 - val_loss: 0.3749 - val_accuracy: 0.8167
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3258 - accuracy: 0.8629 - val_loss: 0.3680 - val_accuracy: 0.8417
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2799 - accuracy: 0.8862 - val_loss: 0.3381 - val_accuracy: 0.8333
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2253 - accuracy: 0.9179 - val_loss: 0.3104 - val_accuracy: 0.8833
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1639 - accuracy: 0.9347 - val_loss: 0.3306 - val_accuracy: 0.8667
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1297 - accuracy: 0.9534 - val_loss: 0.3562 - val_accuracy: 0.8583
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1036 - accuracy: 0.9627 - val_loss: 0.3990 - val_accuracy: 0.8417
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0772 - accuracy: 0.9785 - val_loss: 0.3976 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 270ms/step
#
#  Average Macro F1 is  0.6486693276042124  after running time 6
#
#  Average F1 is  0.839405560882071  after running time 6
#
#  Total AUC is  0.6381308041180169  after running time 6
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5178 - accuracy: 0.8022 - val_loss: 0.4576 - val_accuracy: 0.8333
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4916 - accuracy: 0.8032 - val_loss: 0.4704 - val_accuracy: 0.8333
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4566 - accuracy: 0.8032 - val_loss: 0.4278 - val_accuracy: 0.8333
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4294 - accuracy: 0.8041 - val_loss: 0.4296 - val_accuracy: 0.8333
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3682 - accuracy: 0.8340 - val_loss: 0.3966 - val_accuracy: 0.8500
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3197 - accuracy: 0.8619 - val_loss: 0.4697 - val_accuracy: 0.7417
# Epoch 7/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2919 - accuracy: 0.8881 - val_loss: 0.3879 - val_accuracy: 0.8583
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2055 - accuracy: 0.9170 - val_loss: 0.3687 - val_accuracy: 0.8750
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1605 - accuracy: 0.9412 - val_loss: 0.3403 - val_accuracy: 0.8833
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1496 - accuracy: 0.9524 - val_loss: 0.4298 - val_accuracy: 0.8667
# Epoch 11/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1071 - accuracy: 0.9608 - val_loss: 0.3605 - val_accuracy: 0.8750
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0948 - accuracy: 0.9664 - val_loss: 0.4516 - val_accuracy: 0.8583
# Epoch 13/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0916 - accuracy: 0.9711 - val_loss: 0.4485 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 295ms/step
#
#  Average Macro F1 is  0.6624887050148494  after running time 7
#
#  Average F1 is  0.8456375838926175  after running time 7
#
#  Total AUC is  0.6488123702699314  after running time 7
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5278 - accuracy: 0.8050 - val_loss: 0.4940 - val_accuracy: 0.8083
# Epoch 2/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4715 - accuracy: 0.8144 - val_loss: 0.4799 - val_accuracy: 0.8083
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4538 - accuracy: 0.8144 - val_loss: 0.4729 - val_accuracy: 0.8083
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4123 - accuracy: 0.8162 - val_loss: 0.4563 - val_accuracy: 0.8083
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3651 - accuracy: 0.8256 - val_loss: 0.4462 - val_accuracy: 0.8167
# Epoch 6/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3346 - accuracy: 0.8601 - val_loss: 0.4445 - val_accuracy: 0.7750
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2673 - accuracy: 0.8825 - val_loss: 0.6262 - val_accuracy: 0.8167
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2453 - accuracy: 0.9132 - val_loss: 0.4923 - val_accuracy: 0.7917
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1655 - accuracy: 0.9282 - val_loss: 0.6228 - val_accuracy: 0.8250
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1312 - accuracy: 0.9496 - val_loss: 0.6097 - val_accuracy: 0.8000
# 1/1 [==============================] - 0s 280ms/step
#
#  Average Macro F1 is  0.6581635448073546  after running time 8
#
#  Average F1 is  0.8415361670395227  after running time 8
#
#  Total AUC is  0.6441838687339495  after running time 8
# Epoch 1/100
# 17/17 [==============================] - 2s 42ms/step - loss: 0.5591 - accuracy: 0.7603 - val_loss: 0.4418 - val_accuracy: 0.8500
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4988 - accuracy: 0.8022 - val_loss: 0.4238 - val_accuracy: 0.8500
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4769 - accuracy: 0.8022 - val_loss: 0.4253 - val_accuracy: 0.8500
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4521 - accuracy: 0.8022 - val_loss: 0.4612 - val_accuracy: 0.8500
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4179 - accuracy: 0.8106 - val_loss: 0.4173 - val_accuracy: 0.8417
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3465 - accuracy: 0.8526 - val_loss: 0.3896 - val_accuracy: 0.8583
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3005 - accuracy: 0.8713 - val_loss: 0.4050 - val_accuracy: 0.8250
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2368 - accuracy: 0.9114 - val_loss: 0.4103 - val_accuracy: 0.8667
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1916 - accuracy: 0.9254 - val_loss: 0.4009 - val_accuracy: 0.8500
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1658 - accuracy: 0.9375 - val_loss: 0.4188 - val_accuracy: 0.8583
# 1/1 [==============================] - 0s 283ms/step
#
#  Average Macro F1 is  0.648699109084553  after running time 9
#
#  Average F1 is  0.8422818791946309  after running time 9
#
#  Total AUC is  0.6354863244144436  after running time 9
# Epoch 1/100
# 17/17 [==============================] - 2s 62ms/step - loss: 0.5238 - accuracy: 0.7836 - val_loss: 0.4746 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4627 - accuracy: 0.8172 - val_loss: 0.4714 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4319 - accuracy: 0.8172 - val_loss: 0.4535 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3773 - accuracy: 0.8274 - val_loss: 0.4908 - val_accuracy: 0.8167
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3575 - accuracy: 0.8573 - val_loss: 0.4485 - val_accuracy: 0.7583
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2883 - accuracy: 0.8806 - val_loss: 0.4628 - val_accuracy: 0.7667
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2768 - accuracy: 0.8843 - val_loss: 0.4841 - val_accuracy: 0.7667
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2196 - accuracy: 0.9226 - val_loss: 0.5190 - val_accuracy: 0.7917
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1687 - accuracy: 0.9366 - val_loss: 0.5335 - val_accuracy: 0.8083
# 1/1 [==============================] - 0s 281ms/step
#
#  Average Macro F1 is  0.6553211220886791  after running time 10
#
#  Average F1 is  0.8410616229408177  after running time 10
#
#  Total AUC is  0.6422416188483472  after running time 10
# Epoch 1/100
# 17/17 [==============================] - 2s 46ms/step - loss: 0.5201 - accuracy: 0.8022 - val_loss: 0.4582 - val_accuracy: 0.8250
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4612 - accuracy: 0.8246 - val_loss: 0.4498 - val_accuracy: 0.8250
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4479 - accuracy: 0.8246 - val_loss: 0.4386 - val_accuracy: 0.8250
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4208 - accuracy: 0.8246 - val_loss: 0.4012 - val_accuracy: 0.8250
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4435 - accuracy: 0.8256 - val_loss: 0.4270 - val_accuracy: 0.8250
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3961 - accuracy: 0.8246 - val_loss: 0.3878 - val_accuracy: 0.8250
# Epoch 7/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.3400 - accuracy: 0.8321 - val_loss: 0.3662 - val_accuracy: 0.8333
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2888 - accuracy: 0.8881 - val_loss: 0.3869 - val_accuracy: 0.8417
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2380 - accuracy: 0.9095 - val_loss: 0.3049 - val_accuracy: 0.8750
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1884 - accuracy: 0.9328 - val_loss: 0.3019 - val_accuracy: 0.8750
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1397 - accuracy: 0.9515 - val_loss: 0.3422 - val_accuracy: 0.8667
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1247 - accuracy: 0.9627 - val_loss: 0.3407 - val_accuracy: 0.8583
# Epoch 13/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1088 - accuracy: 0.9646 - val_loss: 0.3202 - val_accuracy: 0.8833
# Epoch 14/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0736 - accuracy: 0.9785 - val_loss: 0.4284 - val_accuracy: 0.8833
# 1/1 [==============================] - 0s 278ms/step
#
#  Average Macro F1 is  0.6602225397973459  after running time 11
#
#  Average F1 is  0.839765100671141  after running time 11
#
#  Total AUC is  0.6460523110119875  after running time 11
# Epoch 1/100
# 17/17 [==============================] - 2s 42ms/step - loss: 0.5125 - accuracy: 0.8106 - val_loss: 0.4854 - val_accuracy: 0.8083
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4618 - accuracy: 0.8181 - val_loss: 0.4824 - val_accuracy: 0.8083
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4508 - accuracy: 0.8181 - val_loss: 0.4940 - val_accuracy: 0.8083
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4384 - accuracy: 0.8181 - val_loss: 0.4768 - val_accuracy: 0.8083
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3972 - accuracy: 0.8181 - val_loss: 0.4668 - val_accuracy: 0.8000
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3397 - accuracy: 0.8554 - val_loss: 0.4772 - val_accuracy: 0.8000
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2876 - accuracy: 0.8797 - val_loss: 0.4531 - val_accuracy: 0.8417
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2214 - accuracy: 0.9207 - val_loss: 0.4487 - val_accuracy: 0.8333
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2342 - accuracy: 0.9104 - val_loss: 0.4694 - val_accuracy: 0.8333
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1550 - accuracy: 0.9450 - val_loss: 0.5859 - val_accuracy: 0.8333
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1155 - accuracy: 0.9590 - val_loss: 0.6930 - val_accuracy: 0.7667
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0851 - accuracy: 0.9720 - val_loss: 0.7241 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 279ms/step
#
#  Average Macro F1 is  0.6626644692290787  after running time 12
#
#  Average F1 is  0.8353123386680434  after running time 12
#
#  Total AUC is  0.6510247318233043  after running time 12
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5297 - accuracy: 0.7854 - val_loss: 0.4480 - val_accuracy: 0.8333
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4780 - accuracy: 0.8153 - val_loss: 0.4426 - val_accuracy: 0.8333
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4731 - accuracy: 0.8153 - val_loss: 0.4378 - val_accuracy: 0.8333
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4467 - accuracy: 0.8153 - val_loss: 0.4149 - val_accuracy: 0.8333
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3981 - accuracy: 0.8209 - val_loss: 0.3814 - val_accuracy: 0.8083
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3433 - accuracy: 0.8535 - val_loss: 0.3618 - val_accuracy: 0.8333
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2856 - accuracy: 0.8778 - val_loss: 0.3091 - val_accuracy: 0.8750
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2629 - accuracy: 0.8927 - val_loss: 0.3306 - val_accuracy: 0.8583
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2074 - accuracy: 0.9207 - val_loss: 0.2631 - val_accuracy: 0.8667
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1587 - accuracy: 0.9496 - val_loss: 0.2633 - val_accuracy: 0.8833
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1170 - accuracy: 0.9543 - val_loss: 0.2746 - val_accuracy: 0.9167
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0994 - accuracy: 0.9664 - val_loss: 0.3463 - val_accuracy: 0.8500
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1274 - accuracy: 0.9468 - val_loss: 0.2698 - val_accuracy: 0.8833
# 1/1 [==============================] - 0s 278ms/step
#
#  Average Macro F1 is  0.6580342039795369  after running time 13
#
#  Average F1 is  0.8307766059443912  after running time 13
#
#  Total AUC is  0.6465737760432596  after running time 13
# Epoch 1/100
# 17/17 [==============================] - 2s 44ms/step - loss: 0.5429 - accuracy: 0.7808 - val_loss: 0.4731 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4850 - accuracy: 0.8041 - val_loss: 0.4698 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4719 - accuracy: 0.8041 - val_loss: 0.4433 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4330 - accuracy: 0.8041 - val_loss: 0.3792 - val_accuracy: 0.8167
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3969 - accuracy: 0.8172 - val_loss: 0.4023 - val_accuracy: 0.8000
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3552 - accuracy: 0.8274 - val_loss: 0.3343 - val_accuracy: 0.8417
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3003 - accuracy: 0.8750 - val_loss: 0.3289 - val_accuracy: 0.8417
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2341 - accuracy: 0.9067 - val_loss: 0.2939 - val_accuracy: 0.8833
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1754 - accuracy: 0.9338 - val_loss: 0.3488 - val_accuracy: 0.8667
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1505 - accuracy: 0.9459 - val_loss: 0.3035 - val_accuracy: 0.8917
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1926 - accuracy: 0.9207 - val_loss: 0.4522 - val_accuracy: 0.8167
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1557 - accuracy: 0.9366 - val_loss: 0.3902 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 279ms/step
#
#  Average Macro F1 is  0.6627805234675015  after running time 14
#
#  Average F1 is  0.8328859060402685  after running time 14
#
#  Total AUC is  0.6514330293224416  after running time 14
# Epoch 1/100
# 17/17 [==============================] - 2s 48ms/step - loss: 0.5271 - accuracy: 0.7864 - val_loss: 0.5259 - val_accuracy: 0.7833
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4700 - accuracy: 0.8181 - val_loss: 0.5217 - val_accuracy: 0.7833
# Epoch 3/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4587 - accuracy: 0.8181 - val_loss: 0.4998 - val_accuracy: 0.7833
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4329 - accuracy: 0.8181 - val_loss: 0.5136 - val_accuracy: 0.7833
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4037 - accuracy: 0.8218 - val_loss: 0.4334 - val_accuracy: 0.7917
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3392 - accuracy: 0.8424 - val_loss: 0.4983 - val_accuracy: 0.8083
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2844 - accuracy: 0.8825 - val_loss: 0.4047 - val_accuracy: 0.8417
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2568 - accuracy: 0.8993 - val_loss: 0.3890 - val_accuracy: 0.8583
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1935 - accuracy: 0.9375 - val_loss: 0.4747 - val_accuracy: 0.8417
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1784 - accuracy: 0.9338 - val_loss: 0.4436 - val_accuracy: 0.8417
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1782 - accuracy: 0.9310 - val_loss: 0.4327 - val_accuracy: 0.8250
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1202 - accuracy: 0.9571 - val_loss: 0.5792 - val_accuracy: 0.8000
# 1/1 [==============================] - 0s 295ms/step
#
#  Average Macro F1 is  0.6623415308932548  after running time 15
#
#  Average F1 is  0.8307466442953021  after running time 15
#
#  Total AUC is  0.651105498035766  after running time 15
# Epoch 1/100
# 17/17 [==============================] - 2s 43ms/step - loss: 0.5420 - accuracy: 0.7687 - val_loss: 0.5330 - val_accuracy: 0.7833
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4723 - accuracy: 0.8144 - val_loss: 0.5228 - val_accuracy: 0.7833
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4567 - accuracy: 0.8144 - val_loss: 0.5107 - val_accuracy: 0.7833
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4274 - accuracy: 0.8144 - val_loss: 0.5029 - val_accuracy: 0.7833
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3728 - accuracy: 0.8265 - val_loss: 0.4896 - val_accuracy: 0.7917
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3412 - accuracy: 0.8517 - val_loss: 0.5441 - val_accuracy: 0.7917
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2611 - accuracy: 0.9039 - val_loss: 0.5921 - val_accuracy: 0.7833
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2301 - accuracy: 0.9142 - val_loss: 0.5856 - val_accuracy: 0.7750
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1526 - accuracy: 0.9394 - val_loss: 0.6540 - val_accuracy: 0.7500
# 1/1 [==============================] - 0s 288ms/step
#
#  Average Macro F1 is  0.6611734782695448  after running time 16
#
#  Average F1 is  0.831030398736676  after running time 16
#
#  Total AUC is  0.6491814737754386  after running time 16
# Epoch 1/100
# 17/17 [==============================] - 2s 47ms/step - loss: 0.5241 - accuracy: 0.8116 - val_loss: 0.4446 - val_accuracy: 0.8417
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4738 - accuracy: 0.8144 - val_loss: 0.4230 - val_accuracy: 0.8417
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4613 - accuracy: 0.8144 - val_loss: 0.3993 - val_accuracy: 0.8417
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4259 - accuracy: 0.8144 - val_loss: 0.3769 - val_accuracy: 0.8417
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3852 - accuracy: 0.8228 - val_loss: 0.3753 - val_accuracy: 0.8667
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3251 - accuracy: 0.8619 - val_loss: 0.3625 - val_accuracy: 0.8333
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2643 - accuracy: 0.8909 - val_loss: 0.3323 - val_accuracy: 0.9000
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2256 - accuracy: 0.9151 - val_loss: 0.4191 - val_accuracy: 0.8333
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1661 - accuracy: 0.9375 - val_loss: 0.3131 - val_accuracy: 0.8917
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1403 - accuracy: 0.9496 - val_loss: 0.3555 - val_accuracy: 0.9083
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0805 - accuracy: 0.9813 - val_loss: 0.5023 - val_accuracy: 0.8417
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0713 - accuracy: 0.9785 - val_loss: 0.4507 - val_accuracy: 0.8667
# Epoch 13/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0492 - accuracy: 0.9851 - val_loss: 0.4632 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 277ms/step
#
#  Average Macro F1 is  0.6605321243144568  after running time 17
#
#  Average F1 is  0.8301640566741239  after running time 17
#
#  Total AUC is  0.6480220332646076  after running time 17
# Epoch 1/100
# 17/17 [==============================] - 2s 44ms/step - loss: 0.5162 - accuracy: 0.8106 - val_loss: 0.4370 - val_accuracy: 0.8583
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4856 - accuracy: 0.8125 - val_loss: 0.4007 - val_accuracy: 0.8583
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4664 - accuracy: 0.8125 - val_loss: 0.3877 - val_accuracy: 0.8583
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4360 - accuracy: 0.8134 - val_loss: 0.4020 - val_accuracy: 0.8583
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4121 - accuracy: 0.8181 - val_loss: 0.3935 - val_accuracy: 0.8500
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3403 - accuracy: 0.8526 - val_loss: 0.3183 - val_accuracy: 0.9000
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2881 - accuracy: 0.8899 - val_loss: 0.3095 - val_accuracy: 0.8750
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2282 - accuracy: 0.9123 - val_loss: 0.3331 - val_accuracy: 0.8750
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1732 - accuracy: 0.9366 - val_loss: 0.4361 - val_accuracy: 0.8417
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1494 - accuracy: 0.9515 - val_loss: 0.4065 - val_accuracy: 0.8500
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1078 - accuracy: 0.9618 - val_loss: 0.5326 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 277ms/step
#
#  Average Macro F1 is  0.6606288476042529  after running time 18
#
#  Average F1 is  0.8297421405863653  after running time 18
#
#  Total AUC is  0.6475270825945391  after running time 18
# Epoch 1/100
# 17/17 [==============================] - 2s 66ms/step - loss: 0.5339 - accuracy: 0.7948 - val_loss: 0.5574 - val_accuracy: 0.7583
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4690 - accuracy: 0.8200 - val_loss: 0.5780 - val_accuracy: 0.7583
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4559 - accuracy: 0.8200 - val_loss: 0.5605 - val_accuracy: 0.7583
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4273 - accuracy: 0.8200 - val_loss: 0.5444 - val_accuracy: 0.7583
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3679 - accuracy: 0.8377 - val_loss: 0.5211 - val_accuracy: 0.8167
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2857 - accuracy: 0.8843 - val_loss: 0.5082 - val_accuracy: 0.8083
# Epoch 7/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2344 - accuracy: 0.9151 - val_loss: 0.5020 - val_accuracy: 0.8500
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1955 - accuracy: 0.9300 - val_loss: 0.5341 - val_accuracy: 0.8333
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1829 - accuracy: 0.9272 - val_loss: 0.4996 - val_accuracy: 0.8333
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1406 - accuracy: 0.9459 - val_loss: 0.6844 - val_accuracy: 0.8000
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1003 - accuracy: 0.9674 - val_loss: 0.6749 - val_accuracy: 0.8167
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0794 - accuracy: 0.9739 - val_loss: 0.7157 - val_accuracy: 0.8000
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0700 - accuracy: 0.9813 - val_loss: 0.8079 - val_accuracy: 0.8083
# 1/1 [==============================] - 0s 283ms/step
#
#  Average Macro F1 is  0.6664488829644069  after running time 19
#
#  Average F1 is  0.8315436241610739  after running time 19
#
#  Total AUC is  0.653634385740782  after running time 19
# Epoch 1/100
# 17/17 [==============================] - 2s 44ms/step - loss: 0.5328 - accuracy: 0.7817 - val_loss: 0.4200 - val_accuracy: 0.8500
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4722 - accuracy: 0.8153 - val_loss: 0.4073 - val_accuracy: 0.8500
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4507 - accuracy: 0.8153 - val_loss: 0.4374 - val_accuracy: 0.8500
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4292 - accuracy: 0.8162 - val_loss: 0.3744 - val_accuracy: 0.8500
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3887 - accuracy: 0.8200 - val_loss: 0.3685 - val_accuracy: 0.8417
# Epoch 6/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.3319 - accuracy: 0.8666 - val_loss: 0.3326 - val_accuracy: 0.8750
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2681 - accuracy: 0.8890 - val_loss: 0.3773 - val_accuracy: 0.8833
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2266 - accuracy: 0.9114 - val_loss: 0.3269 - val_accuracy: 0.8833
# Epoch 9/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1541 - accuracy: 0.9468 - val_loss: 0.2883 - val_accuracy: 0.9167
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1104 - accuracy: 0.9636 - val_loss: 0.4683 - val_accuracy: 0.8167
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1225 - accuracy: 0.9552 - val_loss: 0.2938 - val_accuracy: 0.9083
# Epoch 12/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0954 - accuracy: 0.9720 - val_loss: 0.4187 - val_accuracy: 0.8667
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0993 - accuracy: 0.9701 - val_loss: 0.3338 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 292ms/step
#
#  Average Macro F1 is  0.6695750402692674  after running time 20
#
#  Average F1 is  0.8322147651006712  after running time 20
#
#  Total AUC is  0.6560625966705121  after running time 20
# Epoch 1/100
# 17/17 [==============================] - 2s 46ms/step - loss: 0.5200 - accuracy: 0.7985 - val_loss: 0.5696 - val_accuracy: 0.7500
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4749 - accuracy: 0.8172 - val_loss: 0.5943 - val_accuracy: 0.7500
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4628 - accuracy: 0.8172 - val_loss: 0.5635 - val_accuracy: 0.7500
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4334 - accuracy: 0.8172 - val_loss: 0.5256 - val_accuracy: 0.7500
# Epoch 5/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4130 - accuracy: 0.8153 - val_loss: 0.5345 - val_accuracy: 0.7500
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3512 - accuracy: 0.8284 - val_loss: 0.4430 - val_accuracy: 0.7833
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2987 - accuracy: 0.8815 - val_loss: 0.4232 - val_accuracy: 0.8667
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2556 - accuracy: 0.8937 - val_loss: 0.4099 - val_accuracy: 0.8833
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2264 - accuracy: 0.9095 - val_loss: 0.4050 - val_accuracy: 0.8333
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1968 - accuracy: 0.9263 - val_loss: 0.4263 - val_accuracy: 0.8750
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1482 - accuracy: 0.9440 - val_loss: 0.5779 - val_accuracy: 0.8083
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1445 - accuracy: 0.9524 - val_loss: 0.5309 - val_accuracy: 0.8583
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0933 - accuracy: 0.9655 - val_loss: 0.6121 - val_accuracy: 0.8417
# 1/1 [==============================] - 1s 605ms/step
#
#  Average Macro F1 is  0.6691638027431768  after running time 21
#
#  Average F1 is  0.8288590604026846  after running time 21
#
#  Total AUC is  0.6582960379917339  after running time 21
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5166 - accuracy: 0.8181 - val_loss: 0.4713 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4692 - accuracy: 0.8200 - val_loss: 0.4635 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4535 - accuracy: 0.8200 - val_loss: 0.4498 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4191 - accuracy: 0.8209 - val_loss: 0.4247 - val_accuracy: 0.8167
# Epoch 5/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3691 - accuracy: 0.8507 - val_loss: 0.4427 - val_accuracy: 0.8000
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3192 - accuracy: 0.8722 - val_loss: 0.4304 - val_accuracy: 0.8167
# Epoch 7/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2627 - accuracy: 0.8993 - val_loss: 0.4111 - val_accuracy: 0.8417
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1886 - accuracy: 0.9356 - val_loss: 0.4779 - val_accuracy: 0.8083
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1424 - accuracy: 0.9496 - val_loss: 0.4601 - val_accuracy: 0.8167
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1291 - accuracy: 0.9580 - val_loss: 0.5187 - val_accuracy: 0.8000
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1115 - accuracy: 0.9636 - val_loss: 0.5260 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 299ms/step
#
#  Average Macro F1 is  0.6728841813320849  after running time 22
#
#  Average F1 is  0.8298803618325066  after running time 22
#
#  Total AUC is  0.6614151112191464  after running time 22
# Epoch 1/100
# 17/17 [==============================] - 2s 47ms/step - loss: 0.5343 - accuracy: 0.7808 - val_loss: 0.4741 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4833 - accuracy: 0.8050 - val_loss: 0.4563 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4604 - accuracy: 0.8050 - val_loss: 0.3921 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4279 - accuracy: 0.8060 - val_loss: 0.3689 - val_accuracy: 0.8083
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4055 - accuracy: 0.8162 - val_loss: 0.3936 - val_accuracy: 0.8333
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3422 - accuracy: 0.8647 - val_loss: 0.3288 - val_accuracy: 0.8750
# Epoch 7/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2914 - accuracy: 0.8871 - val_loss: 0.3388 - val_accuracy: 0.8750
# Epoch 8/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2593 - accuracy: 0.8955 - val_loss: 0.3427 - val_accuracy: 0.9000
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2143 - accuracy: 0.9179 - val_loss: 0.4016 - val_accuracy: 0.8250
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1632 - accuracy: 0.9403 - val_loss: 0.3852 - val_accuracy: 0.8833
# 1/1 [==============================] - 0s 276ms/step
#
#  Average Macro F1 is  0.6728501128893987  after running time 23
#
#  Average F1 is  0.8309563758389262  after running time 23
#
#  Total AUC is  0.660717259362793  after running time 23
# Epoch 1/100
# 17/17 [==============================] - 3s 45ms/step - loss: 0.5505 - accuracy: 0.7761 - val_loss: 0.4267 - val_accuracy: 0.8500
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4908 - accuracy: 0.8097 - val_loss: 0.4282 - val_accuracy: 0.8500
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4839 - accuracy: 0.8097 - val_loss: 0.4236 - val_accuracy: 0.8500
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4757 - accuracy: 0.8097 - val_loss: 0.4063 - val_accuracy: 0.8500
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4474 - accuracy: 0.8097 - val_loss: 0.3718 - val_accuracy: 0.8500
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3752 - accuracy: 0.8246 - val_loss: 0.3407 - val_accuracy: 0.8500
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3393 - accuracy: 0.8666 - val_loss: 0.3663 - val_accuracy: 0.8667
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3085 - accuracy: 0.8731 - val_loss: 0.3610 - val_accuracy: 0.8500
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2514 - accuracy: 0.9030 - val_loss: 0.3416 - val_accuracy: 0.8833
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1923 - accuracy: 0.9263 - val_loss: 0.3330 - val_accuracy: 0.8750
# Epoch 11/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1609 - accuracy: 0.9403 - val_loss: 0.3435 - val_accuracy: 0.8583
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1137 - accuracy: 0.9618 - val_loss: 0.4003 - val_accuracy: 0.8917
# Epoch 13/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0845 - accuracy: 0.9729 - val_loss: 0.4270 - val_accuracy: 0.9000
# Epoch 14/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0680 - accuracy: 0.9776 - val_loss: 0.4356 - val_accuracy: 0.8750
# 1/1 [==============================] - 0s 284ms/step
#
#  Average Macro F1 is  0.6714981238776987  after running time 24
#
#  Average F1 is  0.831006711409396  after running time 24
#
#  Total AUC is  0.6588878264680804  after running time 24
# Epoch 1/100
# 17/17 [==============================] - 2s 44ms/step - loss: 0.5145 - accuracy: 0.8153 - val_loss: 0.4659 - val_accuracy: 0.8250
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4667 - accuracy: 0.8228 - val_loss: 0.4607 - val_accuracy: 0.8250
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4515 - accuracy: 0.8228 - val_loss: 0.4473 - val_accuracy: 0.8250
# Epoch 4/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4357 - accuracy: 0.8228 - val_loss: 0.4286 - val_accuracy: 0.8250
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3835 - accuracy: 0.8321 - val_loss: 0.4188 - val_accuracy: 0.8167
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3534 - accuracy: 0.8517 - val_loss: 0.3806 - val_accuracy: 0.8417
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2940 - accuracy: 0.8825 - val_loss: 0.3657 - val_accuracy: 0.8250
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2362 - accuracy: 0.9104 - val_loss: 0.3636 - val_accuracy: 0.8583
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1756 - accuracy: 0.9338 - val_loss: 0.5052 - val_accuracy: 0.8417
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1837 - accuracy: 0.9347 - val_loss: 0.3823 - val_accuracy: 0.8583
# Epoch 11/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.1069 - accuracy: 0.9683 - val_loss: 0.4279 - val_accuracy: 0.8583
# Epoch 12/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0794 - accuracy: 0.9757 - val_loss: 0.5930 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 277ms/step
#
#  Average Macro F1 is  0.6732973233794938  after running time 25
#
#  Average F1 is  0.8305369127516778  after running time 25
#
#  Total AUC is  0.6605207066422866  after running time 25
# Epoch 1/100
# 17/17 [==============================] - 2s 44ms/step - loss: 0.5284 - accuracy: 0.8069 - val_loss: 0.4981 - val_accuracy: 0.8000
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4832 - accuracy: 0.8069 - val_loss: 0.4909 - val_accuracy: 0.8000
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4592 - accuracy: 0.8069 - val_loss: 0.5063 - val_accuracy: 0.8000
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4399 - accuracy: 0.8069 - val_loss: 0.4847 - val_accuracy: 0.8000
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3962 - accuracy: 0.8125 - val_loss: 0.4862 - val_accuracy: 0.8000
# Epoch 6/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.3322 - accuracy: 0.8526 - val_loss: 0.4714 - val_accuracy: 0.7917
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2772 - accuracy: 0.8862 - val_loss: 0.4687 - val_accuracy: 0.7833
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2039 - accuracy: 0.9254 - val_loss: 0.5273 - val_accuracy: 0.8333
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1927 - accuracy: 0.9226 - val_loss: 0.5113 - val_accuracy: 0.8250
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1828 - accuracy: 0.9235 - val_loss: 0.5318 - val_accuracy: 0.7417
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1373 - accuracy: 0.9534 - val_loss: 0.5597 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 293ms/step
#
#  Average Macro F1 is  0.674251256737204  after running time 26
#
#  Average F1 is  0.8314690529455631  after running time 26
#
#  Total AUC is  0.6611804335567698  after running time 26
# Epoch 1/100
# 17/17 [==============================] - 2s 45ms/step - loss: 0.5186 - accuracy: 0.8088 - val_loss: 0.4747 - val_accuracy: 0.8167
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4904 - accuracy: 0.8097 - val_loss: 0.4662 - val_accuracy: 0.8167
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4735 - accuracy: 0.8097 - val_loss: 0.4562 - val_accuracy: 0.8167
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4533 - accuracy: 0.8097 - val_loss: 0.4564 - val_accuracy: 0.8167
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4226 - accuracy: 0.8106 - val_loss: 0.4327 - val_accuracy: 0.8167
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3396 - accuracy: 0.8442 - val_loss: 0.3998 - val_accuracy: 0.8250
# Epoch 7/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2964 - accuracy: 0.8787 - val_loss: 0.4282 - val_accuracy: 0.8333
# Epoch 8/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2494 - accuracy: 0.8993 - val_loss: 0.4116 - val_accuracy: 0.8500
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1867 - accuracy: 0.9328 - val_loss: 0.4542 - val_accuracy: 0.8333
# Epoch 10/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.1497 - accuracy: 0.9403 - val_loss: 0.5203 - val_accuracy: 0.8250
# 1/1 [==============================] - 0s 296ms/step
#
#  Average Macro F1 is  0.6704551191959371  after running time 27
#
#  Average F1 is  0.8317353787152445  after running time 27
#
#  Total AUC is  0.6576367074724565  after running time 27
# Epoch 1/100
# 17/17 [==============================] - 2s 47ms/step - loss: 0.5287 - accuracy: 0.7938 - val_loss: 0.5080 - val_accuracy: 0.8000
# Epoch 2/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4901 - accuracy: 0.8022 - val_loss: 0.4864 - val_accuracy: 0.8000
# Epoch 3/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4686 - accuracy: 0.8022 - val_loss: 0.4551 - val_accuracy: 0.8000
# Epoch 4/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4069 - accuracy: 0.8097 - val_loss: 0.4080 - val_accuracy: 0.8083
# Epoch 5/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.3726 - accuracy: 0.8405 - val_loss: 0.4187 - val_accuracy: 0.7917
# Epoch 6/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.3220 - accuracy: 0.8731 - val_loss: 0.4411 - val_accuracy: 0.7667
# Epoch 7/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2560 - accuracy: 0.8937 - val_loss: 0.5500 - val_accuracy: 0.8167
# Epoch 8/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1990 - accuracy: 0.9170 - val_loss: 0.4686 - val_accuracy: 0.8083
# 1/1 [==============================] - 0s 280ms/step
#
#  Average Macro F1 is  0.667019731110415  after running time 28
#
#  Average F1 is  0.8320990511455681  after running time 28
#
#  Total AUC is  0.6542639493315521  after running time 28
# Epoch 1/100
# 17/17 [==============================] - 2s 43ms/step - loss: 0.5234 - accuracy: 0.7929 - val_loss: 0.5113 - val_accuracy: 0.7917
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4852 - accuracy: 0.8088 - val_loss: 0.5094 - val_accuracy: 0.7917
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4663 - accuracy: 0.8088 - val_loss: 0.4573 - val_accuracy: 0.7917
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4263 - accuracy: 0.8106 - val_loss: 0.4126 - val_accuracy: 0.7917
# Epoch 5/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3842 - accuracy: 0.8190 - val_loss: 0.4036 - val_accuracy: 0.8000
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.3034 - accuracy: 0.8741 - val_loss: 0.3797 - val_accuracy: 0.8333
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2269 - accuracy: 0.9123 - val_loss: 0.3846 - val_accuracy: 0.8500
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2963 - accuracy: 0.8899 - val_loss: 0.4428 - val_accuracy: 0.8167
# Epoch 9/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2257 - accuracy: 0.9244 - val_loss: 0.3364 - val_accuracy: 0.8167
# Epoch 10/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1603 - accuracy: 0.9394 - val_loss: 0.3999 - val_accuracy: 0.8833
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1323 - accuracy: 0.9543 - val_loss: 0.4124 - val_accuracy: 0.8667
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0941 - accuracy: 0.9739 - val_loss: 0.4213 - val_accuracy: 0.8833
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0907 - accuracy: 0.9674 - val_loss: 0.5159 - val_accuracy: 0.8583
# 1/1 [==============================] - 0s 276ms/step
#
#  Average Macro F1 is  0.6692002555990278  after running time 29
#
#  Average F1 is  0.8323266219239375  after running time 29
#
#  Total AUC is  0.6576580032457279  after running time 29
